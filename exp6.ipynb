# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor

# %%
df=pd.read_csv('/content/Cancer_DS.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df, test_size = 0.3)

# %%
trainX = train[df.columns[2:-1]]
trainY=train[df.columns[1]]

testX= test[df.columns[2:-1]]
testY =test[df.columns[1]]

# %%
df['diagnosis']=df['diagnosis'].map({'M':0,'B':1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int64
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
knn=KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(trainX.values,trainY.values)

y_pred = knn.predict(testX.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-1bb1b09b0e63> in <cell line: 3>()
#       1 knn.fit(trainX.values,trainY.values)
#       2
# ----> 3 y_pred = knn.predict(testX.values)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     246
#     247         if weights is None:
# --> 248             y_pred = np.mean(_y[neigh_ind], axis=1)
#     249         else:
#     250             y_pred = np.empty((neigh_dist.shape[0], _y.shape[1]), dtype=np.float64)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in mean(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3430             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3431
# -> 3432     return _methods._mean(a, axis=axis, dtype=dtype,
# ...

# %%
print("Shape of testY:", testY.shape)
print("Shape of y_pred:", y_pred.shape)
# Out:
# Shape of testY: (171,)
# Shape of y_pred: (171,)

# %%
sample_input = []
for i in range(30):
    value = float(input(f"Enter the value for feature {i + 1}: "))
    sample_input.append(value)
# Out:
# Enter the value for feature 1: 15.78
# Enter the value for feature 2: 17.89
# Enter the value for feature 3: 103.6
# Enter the value for feature 4: 781
# Enter the value for feature 5: 0.0971
# Enter the value for feature 6: 0.1292
# Enter the value for feature 7: 0.09954
# Enter the value for feature 8: 0.06606
# Enter the value for feature 9: 0.18432
# Enter the value for feature 10: 0.06082
# Enter the value for feature 11: 0.5058
# Enter the value for feature 12: 0.9849
# Enter the value for feature 13: 3.564
# Enter the value for feature 14: 54.16
# Enter the value for feature 15: 0.005001
# Enter the value for feature 16: 0.04061
# Enter the value for feature 17: 0.02791
# Enter the value for feature 18: 0.01282
# Enter the value for feature 19: 0.02008
# Enter the value for feature 20: 0.004144
# Enter the value for feature 21: 20.42
# Enter the value for feature 22: 27.28
# Enter the value for feature 23: 136.58
# Enter the value for feature 24: 1299
# ...

# %%
k=3

# %%
print(sample_input)
# Out:
# [15.78, 17.89, 103.6, 781.0, 0.0971, 0.1292, 0.09954, 0.06606, 0.18432, 0.06082, 0.5058, 0.9849, 3.564, 54.16, 0.005001, 0.04061, 0.02791, 0.01282, 0.02008, 0.004144, 20.42, 27.28, 136.58, 1299.0, 0.1396, 0.5609, 0.3965, 0.181, 0.3792, 0.1048]

# %%
import numpy as np

# %%
samplearray=np.array(sample_input)

# %%
sample2d=samplearray.reshape(1,-1)

# %%
output = knn.predict(sample2d)
if output==0:
  print("malig")
else:
  print("B vech ollath")
# Out:
# malig
